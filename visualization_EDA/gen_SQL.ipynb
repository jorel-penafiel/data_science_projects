# %% [markdown]
# ## Generate SQL database
#
# This code will try to generate the SQL relational database for the NEB project.  We will generate the database through SQLAlchemy and sqlite

# %%
import sqlalchemy
import pandas as pd

# %%
#Declare a base
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String, Float

# %%
#Declare the three tables we will be using: peaks, markers, and regions
class Peak(Base):
    __tablename__ = 'peaks'
        
    ts_data_id = Column(String, primary_key=True)
    well_id = Column(String, primary_key=True)
    samp_desc = Column(String, nullable=True)
    size = Column(Integer)
    cal_conc = Column(Float)
    assigned_conc = Column(Float, nullable=True)
    peak_mol = Column(Float)
    int_area = Column(Float)
    peak_comment = Column(String, nullable=True)
    observation = Column(String, nullable=True)
    peak_id = Column(Integer, primary_key=True)

# %%
class Marker(Base):
    __tablename__ = 'markers'
    ts_data_id = Column(String, primary_key=True)
    well_id = Column(String, primary_key=True)
    samp_desc = Column(String, nullable=True)
    size = Column(Integer)    
    cal_conc = Column(Float)
    assigned_conc = Column(Float, nullable=True)
    peak_mol = Column(Float)
    int_area = Column(Float, nullable=True)
    peak_comment = Column(String, nullable=True)
    marker_id = Column(String, primary_key=True)

# %%
class Region(Base):
    __tablename__ = 'regions'
    ts_data_id = Column(String, primary_key=True)
    well_id = Column(String, primary_key=True)
    samp_desc = Column(String, nullable=True)
    from_bp = Column(Integer)
    to_bp = Column(Integer)
    avg_size = Column(Integer)
    concentration = Column(Float)
    region_mol = Column(Float)
    pct_total = Column(Float)
    region_comment = Column(String, nullable=True)

# %%
#Declare an engine to work on
from sqlalchemy import create_engine
engine = create_engine('sqlite:///tapestation.db', echo=True)

# %%
Base.metadata.create_all(engine)
# Out:
# 2020-03-20 22:31:36,541 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2020-03-20 22:31:36,543 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,544 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2020-03-20 22:31:36,546 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,548 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("regions")
# 2020-03-20 22:31:36,549 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,551 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("regions")
# 2020-03-20 22:31:36,552 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,554 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("peaks")
# 2020-03-20 22:31:36,555 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,557 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("peaks")
# 2020-03-20 22:31:36,558 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,559 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("markers")
# 2020-03-20 22:31:36,561 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,563 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("markers")
# 2020-03-20 22:31:36,564 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,566 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE regions (
# 	ts_data_id VARCHAR NOT NULL,
# 	well_id VARCHAR NOT NULL,
# 	samp_desc VARCHAR,
# 	from_bp INTEGER,
# 	to_bp INTEGER,
# 	avg_size INTEGER,
# 	concentration FLOAT,
# 	region_mol FLOAT,
# 	pct_total FLOAT,
# 	region_comment VARCHAR,
# 	PRIMARY KEY (ts_data_id, well_id)
# )
#
#
# 2020-03-20 22:31:36,568 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,570 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:36,572 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE peaks (
# 	ts_data_id VARCHAR NOT NULL,
# 	well_id VARCHAR NOT NULL,
# 	samp_desc VARCHAR,
# 	size INTEGER,
# 	cal_conc FLOAT,
# 	assigned_conc FLOAT,
# 	peak_mol FLOAT,
# 	int_area FLOAT,
# 	peak_comment VARCHAR,
# 	observation VARCHAR,
# 	peak_id INTEGER NOT NULL,
# 	PRIMARY KEY (ts_data_id, well_id, peak_id)
# )
#
#
# 2020-03-20 22:31:36,574 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,576 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:36,578 INFO sqlalchemy.engine.base.Engine
# CREATE TABLE markers (
# 	ts_data_id VARCHAR NOT NULL,
# 	well_id VARCHAR NOT NULL,
# 	samp_desc VARCHAR,
# 	size INTEGER,
# 	cal_conc FLOAT,
# 	assigned_conc FLOAT,
# 	peak_mol FLOAT,
# 	int_area FLOAT,
# 	peak_comment VARCHAR,
# 	marker_id VARCHAR NOT NULL,
# 	PRIMARY KEY (ts_data_id, well_id, marker_id)
# )
#
#
# 2020-03-20 22:31:36,579 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:36,582 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
#Starting a session
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)

# %%
session = Session()

# %%
import os
rootdir = '/Users/louispenafiel/Programming/Python/job_hunt/neb/ts_data/'

# %%
conn = engine.connect()

# %%
#Go through list of data directories
for name in os.listdir(rootdir):
    #Each of them ends with a 1000 and avoids callind .DS_Store
    if name.endswith("1000"):
        newdir = rootdir + name + '/'
        #instantiates the filenames
        peaktable_filename = newdir + name + '_compactPeakTable.csv'
        regiontable_filename = newdir + name + '_compactRegionTable.csv'
        
        #create pd dataframes from the filenames
        peaktable_df = pd.read_csv(peaktable_filename)
        regiontable_df = pd.read_csv(regiontable_filename)
        
        ##########################
        # GENERATING PEAKS TABLE #
        ##########################
        
        #Choose only data free from electronic ladders and synthetic markers
        peak_mask = (peaktable_df['Observations'] != 'Lower Marker') & (peaktable_df['Observations'] != 'Upper Marker')
        peak_df = peaktable_df[peak_mask].copy()
        
        #Sort the values by integrated area
        peak_df = peak_df.sort_values(by='% Integrated Area', ascending=False)
        
        #Give each peak a peak_id, depending on the size of the peak
        #Largest peak is assigned 1, second largest 2, ...
        peak_df['Peak_id'] = peak_df.groupby(['FileName','Well']).cumcount() + 1
        
        #Rename columns
        peak_df.columns = ['ts_data_id', 'well_id', 'samp_desc', 'size', 'cal_conc', 'assigned_conc', 'peak_mol', 'int_area', 'peak_comment', 'observation','peak_id']
        peak_df.to_sql('peaks', engine, index=False, if_exists='append')
        
        ############################
        # GENERATING MARKERS TABLE #
        ############################
        
        #Choose only data that correspond to synthetic markers
        marker_mask = (peaktable_df['Observations'] == 'Lower Marker') | (peaktable_df['Observations'] == 'Upper Marker')
        marker_df = peaktable_df[marker_mask].copy()
        
        marker_df.columns = ['ts_data_id', 'well_id', 'samp_desc', 'size', 'cal_conc', 'assigned_conc','peak_mol', 'int_area', 'peak_comment', 'marker_id']
        marker_df.to_sql('markers', engine, index=False, if_exists='append')

        
        ############################
        # GENERATING REGIONS TABLE #
        ############################
        
        region_df = regiontable_df.copy()

        region_df.columns = ['ts_data_id', 'well_id','samp_desc', 'from_bp', 'to_bp', 'avg_size', 'concentration', 'region_mol', 'pct_total', 'region_comment']
        region_df.to_sql('regions', engine, index=False, if_exists='append')
        
        
    else:
        continue
# Out:
# 2020-03-20 22:31:41,961 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("peaks")
# 2020-03-20 22:31:41,962 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:41,964 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:41,969 INFO sqlalchemy.engine.base.Engine INSERT INTO peaks (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, observation, peak_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:41,970 INFO sqlalchemy.engine.base.Engine (('2019-12-18 - 11.45.28.HSD1000', 'H12', None, 295, 3590.0, None, 18700, 100.0, None, None, 1), ('2019-12-18 - 11.45.28.HSD1000', 'G10', None, 293, 3290.0, None, 17300, 100.0, None, None, 1), ('2019-12-18 - 11.45.28.HSD1000', 'G6', None, 302, 7450.0, None, 37900, 100.0, None, None, 1), ('2019-12-18 - 11.45.28.HSD1000', 'F6', None, 310, 6920.0, None, 34400, 100.0, None, None, 1), ('2019-12-18 - 11.45.28.HSD1000', 'D6', None, 320, 10400.0, None, 49800, 100.0, None, None, 1), ('2019-12-18 - 11.45.28.HSD1000', 'C6', None, 316, 11300.0, None, 55100, 100.0, None, None, 1), ('2019-12-18 - 11.45.28.HSD1000', 'B6', None, 298, 14200.0, None, 73000, 100.0, None, None, 1), ('2019-12-18 - 11.45.28.HSD1000', 'A6', None, 301, 9120.0, None, 46700, 100.0, None, None, 1)  ... displaying 10 of 156 total bound parameter sets ...  ('2019-12-18 - 11.45.28.HSD1000', 'H11', None, 146, 55.4, None, 582, 0.69, None, None, 2), ('2019-12-18 - 11.45.28.HSD1000', 'H7', None, 157, 66.8, None, 653, 0.68, None, None, 2))
# 2020-03-20 22:31:41,973 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:41,980 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("markers")
# 2020-03-20 22:31:41,981 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:41,984 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:41,988 INFO sqlalchemy.engine.base.Engine INSERT INTO markers (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, marker_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:41,990 INFO sqlalchemy.engine.base.Engine (('2019-12-18 - 11.45.28.HSD1000', 'EL1', 'Electronic Ladder', 25, 340.0, None, 20900, None, None, 'Lower Marker'), ('2019-12-18 - 11.45.28.HSD1000', 'EL1', 'Electronic Ladder', 1500, 250.0, 250.0, 256, None, None, 'Upper Marker'), ('2019-12-18 - 11.45.28.HSD1000', 'A1', None, 25, 365.0, None, 22500, None, None, 'Lower Marker'), ('2019-12-18 - 11.45.28.HSD1000', 'A1', None, 1500, 250.0, 250.0, 256, None, None, 'Upper Marker'), ('2019-12-18 - 11.45.28.HSD1000', 'B1', None, 25, 411.0, None, 25300, None, None, 'Lower Marker'), ('2019-12-18 - 11.45.28.HSD1000', 'B1', None, 1500, 250.0, 250.0, 256, None, None, 'Upper Marker'), ('2019-12-18 - 11.45.28.HSD1000', 'C1', None, 25, 469.0, None, 28800, None, None, 'Lower Marker'), ('2019-12-18 - 11.45.28.HSD1000', 'C1', None, 1500, 250.0, 250.0, 256, None, None, 'Upper Marker')  ... displaying 10 of 202 total bound parameter sets ...  ('2019-12-18 - 11.45.28.HSD1000', 'H12', None, 25, 446.0, None, 27500, None, None, 'Lower Marker'), ('2019-12-18 - 11.45.28.HSD1000', 'H12', None, 1500, 250.0, 250.0, 256, None, None, 'Upper Marker'))
# 2020-03-20 22:31:41,993 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:41,998 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("regions")
# 2020-03-20 22:31:41,999 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,002 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,005 INFO sqlalchemy.engine.base.Engine INSERT INTO regions (ts_data_id, well_id, samp_desc, from_bp, to_bp, avg_size, concentration, region_mol, pct_total, region_comment) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,006 INFO sqlalchemy.engine.base.Engine (('2019-12-18 - 11.45.28.HSD1000', 'A1', None, 100, 1000, 382, 18000, 78100, 99.5, None), ('2019-12-18 - 11.45.28.HSD1000', 'B1', None, 100, 1000, 383, 13500, 58400, 98.1, None), ('2019-12-18 - 11.45.28.HSD1000', 'C1', None, 100, 1000, 372, 2260, 10000, 96.82, None), ('2019-12-18 - 11.45.28.HSD1000', 'D1', None, 100, 1000, 382, 16000, 68900, 98.68, None), ('2019-12-18 - 11.45.28.HSD1000', 'E1', None, 100, 1000, 384, 13200, 56900, 98.93, None), ('2019-12-18 - 11.45.28.HSD1000', 'F1', None, 100, 1000, 377, 13800, 60300, 98.75, None), ('2019-12-18 - 11.45.28.HSD1000', 'G1', None, 100, 1000, 382, 10500, 44800, 99.01, None), ('2019-12-18 - 11.45.28.HSD1000', 'H1', None, 100, 1000, 375, 14200, 62600, 98.95, None)  ... displaying 10 of 95 total bound parameter sets ...  ('2019-12-18 - 11.45.28.HSD1000', 'G12', None, 100, 1000, 374, 8440, 37600, 98.88, None), ('2019-12-18 - 11.45.28.HSD1000', 'H12', None, 100, 1000, 362, 4440, 20400, 98.44, None))
# 2020-03-20 22:31:42,009 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,026 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("peaks")
# 2020-03-20 22:31:42,028 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,030 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,034 INFO sqlalchemy.engine.base.Engine INSERT INTO peaks (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, observation, peak_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,035 INFO sqlalchemy.engine.base.Engine (('2020-02-27 - 12.12.58.HSD1000', 'H12', None, 275.0, 5580.0, None, 31200.0, 100.0, None, None, 1), ('2020-02-27 - 12.12.58.HSD1000', 'G6', None, 278.0, 5150.0, None, 28500.0, 100.0, None, None, 1), ('2020-02-27 - 12.12.58.HSD1000', 'B8', None, 289.0, 5670.0, None, 30200.0, 100.0, None, None, 1), ('2020-02-27 - 12.12.58.HSD1000', 'A8', None, 284.0, 3830.0, None, 20800.0, 100.0, None, None, 1), ('2020-02-27 - 12.12.58.HSD1000', 'H7', None, 275.0, 4990.0, None, 27900.0, 100.0, None, None, 1), ('2020-02-27 - 12.12.58.HSD1000', 'G7', None, 277.0, 4740.0, None, 26300.0, 100.0, None, None, 1), ('2020-02-27 - 12.12.58.HSD1000', 'F7', None, 284.0, 4890.0, None, 26500.0, 100.0, None, None, 1), ('2020-02-27 - 12.12.58.HSD1000', 'E7', None, 283.0, 4240.0, None, 23000.0, 100.0, None, None, 1)  ... displaying 10 of 149 total bound parameter sets ...  ('2020-02-27 - 12.12.58.HSD1000', 'C3', None, 151.0, 115.0, None, 1170.0, 1.99, None, None, 2), ('2020-02-27 - 12.12.58.HSD1000', 'C11', None, 153.0, 61.1, None, 612.0, 1.1, None, None, 2))
# 2020-03-20 22:31:42,038 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,045 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("markers")
# 2020-03-20 22:31:42,046 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,049 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,053 INFO sqlalchemy.engine.base.Engine INSERT INTO markers (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, marker_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,055 INFO sqlalchemy.engine.base.Engine (('2020-02-27 - 12.12.58.HSD1000', 'EL1', 'Electronic Ladder', 25.0, 340.0, None, 20900.0, None, None, 'Lower Marker'), ('2020-02-27 - 12.12.58.HSD1000', 'EL1', 'Electronic Ladder', 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-27 - 12.12.58.HSD1000', 'A1', None, 25.0, 406.0, None, 25000.0, None, None, 'Lower Marker'), ('2020-02-27 - 12.12.58.HSD1000', 'A1', None, 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-27 - 12.12.58.HSD1000', 'B1', None, 25.0, 410.0, None, 25200.0, None, None, 'Lower Marker'), ('2020-02-27 - 12.12.58.HSD1000', 'B1', None, 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-27 - 12.12.58.HSD1000', 'C1', None, 25.0, 419.0, None, 25800.0, None, None, 'Lower Marker'), ('2020-02-27 - 12.12.58.HSD1000', 'C1', None, 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker')  ... displaying 10 of 203 total bound parameter sets ...  ('2020-02-27 - 12.12.58.HSD1000', 'H12', None, 25.0, 420.0, None, 25900.0, None, None, 'Lower Marker'), ('2020-02-27 - 12.12.58.HSD1000', 'H12', None, 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker'))
# 2020-03-20 22:31:42,058 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,063 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("regions")
# 2020-03-20 22:31:42,064 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,067 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,070 INFO sqlalchemy.engine.base.Engine INSERT INTO regions (ts_data_id, well_id, samp_desc, from_bp, to_bp, avg_size, concentration, region_mol, pct_total, region_comment) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,071 INFO sqlalchemy.engine.base.Engine (('2020-02-27 - 12.12.58.HSD1000', 'A1', None, 100, 1000, 338, 7510, 36700, 98.82, None), ('2020-02-27 - 12.12.58.HSD1000', 'B1', None, 100, 1000, 337, 6310, 30900, 97.89, None), ('2020-02-27 - 12.12.58.HSD1000', 'C1', None, 177, 1000, 329, 7270, 36400, 96.67, None), ('2020-02-27 - 12.12.58.HSD1000', 'D1', None, 100, 1000, 333, 5820, 28700, 98.71, None), ('2020-02-27 - 12.12.58.HSD1000', 'E1', None, 100, 1000, 323, 6020, 30400, 98.76, None), ('2020-02-27 - 12.12.58.HSD1000', 'F1', None, 100, 1000, 327, 5990, 29900, 98.45, None), ('2020-02-27 - 12.12.58.HSD1000', 'G1', None, 100, 1000, 320, 6290, 32100, 98.79, None), ('2020-02-27 - 12.12.58.HSD1000', 'H1', None, 100, 1000, 322, 7000, 35600, 98.75, None)  ... displaying 10 of 95 total bound parameter sets ...  ('2020-02-27 - 12.12.58.HSD1000', 'G12', None, 100, 1000, 319, 6110, 31400, 98.89, None), ('2020-02-27 - 12.12.58.HSD1000', 'H12', None, 100, 1000, 316, 6550, 33900, 98.66, None))
# 2020-03-20 22:31:42,073 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,090 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("peaks")
# 2020-03-20 22:31:42,092 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,095 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,098 INFO sqlalchemy.engine.base.Engine INSERT INTO peaks (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, observation, peak_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,099 INFO sqlalchemy.engine.base.Engine (('2020-02-26 - 13.53.51.HSD1000', 'F11', '14-B-100', 619, 1350.0, None, 3350.0, 100.0, None, None, 1), ('2020-02-26 - 13.53.51.HSD1000', 'E11', '13-B-100', 622, 1600.0, None, 3960.0, 100.0, None, None, 1), ('2020-02-26 - 13.53.51.HSD1000', 'B11', '10-T-100', 638, 1960.0, None, 4720.0, 96.37, None, None, 1), ('2020-02-26 - 13.53.51.HSD1000', 'A11', '09-T-100', 637, 1590.0, None, 3830.0, 95.91, None, None, 1), ('2020-02-26 - 13.53.51.HSD1000', 'C10', '03-PB-extract', 640, 1920.0, None, 4620.0, 93.15, None, None, 1), ('2020-02-26 - 13.53.51.HSD1000', 'E10', '05-PB-RNA-100', 639, 1550.0, None, 3740.0, 91.08, None, None, 1), ('2020-02-26 - 13.53.51.HSD1000', 'F10', '06-PB-RNA-100', 640, 1550.0, None, 3740.0, 90.7, None, None, 1), ('2020-02-26 - 13.53.51.HSD1000', 'D10', '04-PB-extract', 642, 2120.0, None, 5070.0, 90.29, None, None, 1)  ... displaying 10 of 55 total bound parameter sets ...  ('2020-02-26 - 13.53.51.HSD1000', 'A10', '01-PB-lysate', 178, 4.25, None, 36.8, 1.02, None, None, 7), ('2020-02-26 - 13.53.51.HSD1000', 'H10', '08-PB-RNA-10', 310, 19.7, None, 97.7, 1.01, None, None, 4))
# 2020-03-20 22:31:42,101 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,108 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("markers")
# 2020-03-20 22:31:42,109 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,111 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,114 INFO sqlalchemy.engine.base.Engine INSERT INTO markers (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, marker_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,115 INFO sqlalchemy.engine.base.Engine (('2020-02-26 - 13.53.51.HSD1000', 'EL1', 'Electronic Ladder', 25, 340.0, None, 20900.0, None, None, 'Lower Marker'), ('2020-02-26 - 13.53.51.HSD1000', 'EL1', 'Electronic Ladder', 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-26 - 13.53.51.HSD1000', 'A10', '01-PB-lysate', 25, 388.0, None, 23900.0, None, None, 'Lower Marker'), ('2020-02-26 - 13.53.51.HSD1000', 'A10', '01-PB-lysate', 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-26 - 13.53.51.HSD1000', 'B10', '02-PB-lysate', 25, 385.0, None, 23700.0, None, None, 'Lower Marker'), ('2020-02-26 - 13.53.51.HSD1000', 'B10', '02-PB-lysate', 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-26 - 13.53.51.HSD1000', 'C10', '03-PB-extract', 25, 363.0, None, 22300.0, None, None, 'Lower Marker'), ('2020-02-26 - 13.53.51.HSD1000', 'C10', '03-PB-extract', 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker')  ... displaying 10 of 34 total bound parameter sets ...  ('2020-02-26 - 13.53.51.HSD1000', 'H11', '16-B-10', 25, 405.0, None, 24900.0, None, None, 'Lower Marker'), ('2020-02-26 - 13.53.51.HSD1000', 'H11', '16-B-10', 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'))
# 2020-03-20 22:31:42,118 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,122 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("regions")
# 2020-03-20 22:31:42,124 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,126 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,128 INFO sqlalchemy.engine.base.Engine INSERT INTO regions (ts_data_id, well_id, samp_desc, from_bp, to_bp, avg_size, concentration, region_mol, pct_total, region_comment) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,129 INFO sqlalchemy.engine.base.Engine (('2020-02-26 - 13.53.51.HSD1000', 'A10', '01-PB-lysate', 100, 1000, 439, 471.0, 1780, 83.86, None), ('2020-02-26 - 13.53.51.HSD1000', 'B10', '02-PB-lysate', 100, 1000, 410, 414.0, 1670, 84.45, None), ('2020-02-26 - 13.53.51.HSD1000', 'C10', '03-PB-extract', 100, 1000, 617, 2580.0, 7270, 95.52, None), ('2020-02-26 - 13.53.51.HSD1000', 'D10', '04-PB-extract', 100, 1000, 634, 2710.0, 6830, 95.68, None), ('2020-02-26 - 13.53.51.HSD1000', 'E10', '05-PB-RNA-100', 100, 1000, 629, 2050.0, 5190, 95.24, None), ('2020-02-26 - 13.53.51.HSD1000', 'F10', '06-PB-RNA-100', 100, 1000, 629, 2060.0, 5220, 94.87, None), ('2020-02-26 - 13.53.51.HSD1000', 'G10', '07-PB-RNA-10', 100, 1000, 622, 2160.0, 5540, 95.08, None), ('2020-02-26 - 13.53.51.HSD1000', 'H10', '08-PB-RNA-10', 100, 1000, 607, 2300.0, 6100, 97.28, None)  ... displaying 10 of 16 total bound parameter sets ...  ('2020-02-26 - 13.53.51.HSD1000', 'G11', '15-B-10', 100, 1000, 566, 233.0, 683, 80.46, None), ('2020-02-26 - 13.53.51.HSD1000', 'H11', '16-B-10', 100, 1000, 572, 341.0, 992, 84.13, None))
# 2020-03-20 22:31:42,132 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,149 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("peaks")
# 2020-03-20 22:31:42,150 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,153 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,156 INFO sqlalchemy.engine.base.Engine INSERT INTO peaks (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, observation, peak_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,158 INFO sqlalchemy.engine.base.Engine (('2020-02-03 - 11.25.42.HSD1000', 'C4', 'Lot53_+DTT_1', 439.0, 2450.0, None, 8560.0, 100.0, None, None, 1), ('2020-02-03 - 11.25.42.HSD1000', 'H5', 'ZnLot1_16_+DTT_2', 432.0, 366.0, None, 1300.0, 100.0, None, None, 1), ('2020-02-03 - 11.25.42.HSD1000', 'D3', 'Lot43_+DTT_2', 427.0, 836.0, None, 3010.0, 100.0, None, None, 1), ('2020-02-03 - 11.25.42.HSD1000', 'E3', 'Lot46_-DTT_1', 350.0, 30.8, None, 135.0, 100.0, None, None, 1), ('2020-02-03 - 11.25.42.HSD1000', 'G3', 'Lot46_+DTT_1', 457.0, 521.0, None, 1760.0, 100.0, None, None, 1), ('2020-02-03 - 11.25.42.HSD1000', 'H3', 'Lot46_+DTT_2', 456.0, 2200.0, None, 7430.0, 100.0, None, None, 1), ('2020-02-03 - 11.25.42.HSD1000', 'A4', 'Lot53_-DTT_1', 414.0, 129.0, None, 481.0, 100.0, None, None, 1), ('2020-02-03 - 11.25.42.HSD1000', 'B4', 'Lot53_-DTT_2', 455.0, 143.0, None, 483.0, 100.0, None, None, 1)  ... displaying 10 of 89 total bound parameter sets ...  ('2020-02-03 - 11.25.42.HSD1000', 'A6', 'ZnLot2_8_-DTT_1', 523.0, 3.47, None, 10.2, 9.3, None, None, 2), ('2020-02-03 - 11.25.42.HSD1000', 'E1', 'Lot23_-DTT_1', 71.0, 14.7, None, 317.0, 5.73, None, None, 2))
# 2020-03-20 22:31:42,160 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,167 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("markers")
# 2020-03-20 22:31:42,168 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,171 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,175 INFO sqlalchemy.engine.base.Engine INSERT INTO markers (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, marker_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,176 INFO sqlalchemy.engine.base.Engine (('2020-02-03 - 11.25.42.HSD1000', 'EL1', 'Electronic Ladder', 25.0, 340.0, None, 20900.0, None, None, 'Lower Marker'), ('2020-02-03 - 11.25.42.HSD1000', 'EL1', 'Electronic Ladder', 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-03 - 11.25.42.HSD1000', 'A1', 'Lot41_-DTT_1', 25.0, 355.0, None, 21800.0, None, None, 'Lower Marker'), ('2020-02-03 - 11.25.42.HSD1000', 'A1', 'Lot41_-DTT_1', 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-03 - 11.25.42.HSD1000', 'B1', 'Lot41_-DTT_2', 25.0, 437.0, None, 26900.0, None, None, 'Lower Marker'), ('2020-02-03 - 11.25.42.HSD1000', 'B1', 'Lot41_-DTT_2', 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-03 - 11.25.42.HSD1000', 'C1', 'Lot41_+DTT_1', 25.0, 352.0, None, 21600.0, None, None, 'Lower Marker'), ('2020-02-03 - 11.25.42.HSD1000', 'C1', 'Lot41_+DTT_1', 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker')  ... displaying 10 of 107 total bound parameter sets ...  ('2020-02-03 - 11.25.42.HSD1000', 'H7', 'ZnLot3_16_+DTT_2', 25.0, 464.0, None, 28500.0, None, None, 'Lower Marker'), ('2020-02-03 - 11.25.42.HSD1000', 'H7', 'ZnLot3_16_+DTT_2', 1500.0, 250.0, 250.0, 256.0, None, None, 'Upper Marker'))
# 2020-03-20 22:31:42,178 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,183 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("regions")
# 2020-03-20 22:31:42,185 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,187 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,190 INFO sqlalchemy.engine.base.Engine INSERT INTO regions (ts_data_id, well_id, samp_desc, from_bp, to_bp, avg_size, concentration, region_mol, pct_total, region_comment) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,191 INFO sqlalchemy.engine.base.Engine (('2020-02-03 - 11.25.42.HSD1000', 'A1', 'Lot41_-DTT_1', 100, 1000, 518, 2920.0, 9620, 95.78, None), ('2020-02-03 - 11.25.42.HSD1000', 'B1', 'Lot41_-DTT_2', 100, 1000, 529, 3530.0, 11200, 91.67, None), ('2020-02-03 - 11.25.42.HSD1000', 'C1', 'Lot41_+DTT_1', 100, 1000, 513, 6610.0, 21900, 96.9, None), ('2020-02-03 - 11.25.42.HSD1000', 'D1', 'Lot41_+DTT_2', 100, 1000, 479, 4260.0, 15500, 98.31, None), ('2020-02-03 - 11.25.42.HSD1000', 'E1', 'Lot23_-DTT_1', 100, 1000, 445, 1170.0, 4540, 92.13, None), ('2020-02-03 - 11.25.42.HSD1000', 'F1', 'Lot23_-DTT_2', 100, 1000, 473, 1830.0, 6720, 96.13, None), ('2020-02-03 - 11.25.42.HSD1000', 'G1', 'Lot23_+DTT_1', 100, 1000, 495, 3350.0, 11500, 96.48, None), ('2020-02-03 - 11.25.42.HSD1000', 'H1', 'Lot23_+DTT_2', 100, 1000, 489, 4040.0, 14100, 97.35, None)  ... displaying 10 of 49 total bound parameter sets ...  ('2020-02-03 - 11.25.42.HSD1000', 'G7', 'ZnLot3_16_+DTT_1', 100, 1000, 474, 4340.0, 15500, 97.3, None), ('2020-02-03 - 11.25.42.HSD1000', 'H7', 'ZnLot3_16_+DTT_2', 100, 1000, 480, 6110.0, 21600, 96.77, None))
# 2020-03-20 22:31:42,194 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,212 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("peaks")
# 2020-03-20 22:31:42,213 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,216 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,220 INFO sqlalchemy.engine.base.Engine INSERT INTO peaks (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, observation, peak_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,222 INFO sqlalchemy.engine.base.Engine (('2020-03-03 - 16.22.56.HSD1000', 'H6', None, 320, 253.0, None, 1220.0, 100.0, None, None, 1), ('2020-03-03 - 16.22.56.HSD1000', 'B7', None, 330, 259.0, None, 1210.0, 100.0, None, None, 1), ('2020-03-03 - 16.22.56.HSD1000', 'G8', None, 307, 245.0, None, 1230.0, 100.0, None, None, 1), ('2020-03-03 - 16.22.56.HSD1000', 'F8', None, 314, 310.0, None, 1520.0, 100.0, None, None, 1), ('2020-03-03 - 16.22.56.HSD1000', 'D8', None, 317, 52.1, None, 253.0, 100.0, None, None, 1), ('2020-03-03 - 16.22.56.HSD1000', 'C8', None, 321, 264.0, None, 1260.0, 100.0, None, None, 1), ('2020-03-03 - 16.22.56.HSD1000', 'B8', None, 320, 255.0, None, 1220.0, 100.0, None, None, 1), ('2020-03-03 - 16.22.56.HSD1000', 'A8', None, 327, 224.0, None, 1060.0, 100.0, None, None, 1)  ... displaying 10 of 157 total bound parameter sets ...  ('2020-03-03 - 16.22.56.HSD1000', 'H4', None, 2010, 4.16, None, 3.18, 1.52, None, None, 2), ('2020-03-03 - 16.22.56.HSD1000', 'E8', None, 58, 3.39, None, 89.5, 1.49, None, None, 2))
# 2020-03-20 22:31:42,225 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,232 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("markers")
# 2020-03-20 22:31:42,233 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,235 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,240 INFO sqlalchemy.engine.base.Engine INSERT INTO markers (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, marker_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,241 INFO sqlalchemy.engine.base.Engine (('2020-03-03 - 16.22.56.HSD1000', 'EL1', 'Electronic Ladder', 25, 340.0, None, 20900.0, None, None, 'Lower Marker'), ('2020-03-03 - 16.22.56.HSD1000', 'EL1', 'Electronic Ladder', 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-03-03 - 16.22.56.HSD1000', 'A1', None, 25, 474.0, None, 29200.0, None, None, 'Lower Marker'), ('2020-03-03 - 16.22.56.HSD1000', 'A1', None, 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-03-03 - 16.22.56.HSD1000', 'B1', None, 25, 453.0, None, 27900.0, None, None, 'Lower Marker'), ('2020-03-03 - 16.22.56.HSD1000', 'B1', None, 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-03-03 - 16.22.56.HSD1000', 'C1', None, 25, 436.0, None, 26800.0, None, None, 'Lower Marker'), ('2020-03-03 - 16.22.56.HSD1000', 'C1', None, 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker')  ... displaying 10 of 204 total bound parameter sets ...  ('2020-03-03 - 16.22.56.HSD1000', 'H12', None, 25, 388.0, None, 23900.0, None, None, 'Lower Marker'), ('2020-03-03 - 16.22.56.HSD1000', 'H12', None, 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'))
# 2020-03-20 22:31:42,244 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,249 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("regions")
# 2020-03-20 22:31:42,251 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,253 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,256 INFO sqlalchemy.engine.base.Engine INSERT INTO regions (ts_data_id, well_id, samp_desc, from_bp, to_bp, avg_size, concentration, region_mol, pct_total, region_comment) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,258 INFO sqlalchemy.engine.base.Engine (('2020-03-03 - 16.22.56.HSD1000', 'A1', None, 100, 1000, 363, 847, 3880, 89.89, None), ('2020-03-03 - 16.22.56.HSD1000', 'B1', None, 100, 1000, 369, 840, 3810, 93.06, None), ('2020-03-03 - 16.22.56.HSD1000', 'C1', None, 100, 1000, 350, 904, 4550, 93.05, None), ('2020-03-03 - 16.22.56.HSD1000', 'D1', None, 100, 1000, 358, 621, 2930, 90.37, None), ('2020-03-03 - 16.22.56.HSD1000', 'E1', None, 100, 1000, 367, 793, 3610, 89.79, None), ('2020-03-03 - 16.22.56.HSD1000', 'F1', None, 100, 1000, 359, 866, 4010, 93.14, None), ('2020-03-03 - 16.22.56.HSD1000', 'G1', None, 100, 1000, 359, 755, 3510, 90.41, None), ('2020-03-03 - 16.22.56.HSD1000', 'H1', None, 100, 1000, 355, 754, 3540, 92.77, None)  ... displaying 10 of 96 total bound parameter sets ...  ('2020-03-03 - 16.22.56.HSD1000', 'G12', None, 100, 1000, 351, 680, 3220, 90.0, None), ('2020-03-03 - 16.22.56.HSD1000', 'H12', None, 100, 1000, 349, 644, 3110, 92.63, None))
# 2020-03-20 22:31:42,261 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,279 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("peaks")
# 2020-03-20 22:31:42,281 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,283 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,289 INFO sqlalchemy.engine.base.Engine INSERT INTO peaks (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, observation, peak_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,290 INFO sqlalchemy.engine.base.Engine (('2020-02-11 - 10.01.14.HSD1000', 'H7', None, 321, 1470.0, None, 7060.0, 95.22, None, None, 1), ('2020-02-11 - 10.01.14.HSD1000', 'F4', None, 154, 836.0, None, 8340.0, 95.16, None, None, 1), ('2020-02-11 - 10.01.14.HSD1000', 'G9', None, 314, 731.0, None, 3580.0, 93.8, None, None, 1), ('2020-02-11 - 10.01.14.HSD1000', 'C7', None, 313, 832.0, None, 4090.0, 93.05, None, None, 1), ('2020-02-11 - 10.01.14.HSD1000', 'D6', None, 156, 1200.0, None, 11800.0, 92.91, None, None, 1), ('2020-02-11 - 10.01.14.HSD1000', 'E7', None, 314, 862.0, None, 4230.0, 92.79, None, None, 1), ('2020-02-11 - 10.01.14.HSD1000', 'G3', None, 152, 132.0, None, 1340.0, 91.98, None, None, 1), ('2020-02-11 - 10.01.14.HSD1000', 'H9', None, 339, 366.0, None, 1660.0, 91.6, None, None, 1)  ... displaying 10 of 269 total bound parameter sets ...  ('2020-02-11 - 10.01.14.HSD1000', 'A1', '2020_02_08_Rio_P11_A1', 83, 2.57, None, 47.6, 0.89, None, None, 4), ('2020-02-11 - 10.01.14.HSD1000', 'H7', None, 12, 11.1, None, 1400.0, 0.72, None, None, 4))
# 2020-03-20 22:31:42,294 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,301 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("markers")
# 2020-03-20 22:31:42,303 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,305 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,310 INFO sqlalchemy.engine.base.Engine INSERT INTO markers (ts_data_id, well_id, samp_desc, size, cal_conc, assigned_conc, peak_mol, int_area, peak_comment, marker_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,312 INFO sqlalchemy.engine.base.Engine (('2020-02-11 - 10.01.14.HSD1000', 'EL1', 'Electronic Ladder', 25, 340.0, None, 20900.0, None, None, 'Lower Marker'), ('2020-02-11 - 10.01.14.HSD1000', 'EL1', 'Electronic Ladder', 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-11 - 10.01.14.HSD1000', 'A1', '2020_02_08_Rio_P11_A1', 25, 397.0, None, 24400.0, None, None, 'Lower Marker'), ('2020-02-11 - 10.01.14.HSD1000', 'A1', '2020_02_08_Rio_P11_A1', 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-11 - 10.01.14.HSD1000', 'B1', None, 25, 388.0, None, 23900.0, None, None, 'Lower Marker'), ('2020-02-11 - 10.01.14.HSD1000', 'B1', None, 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'), ('2020-02-11 - 10.01.14.HSD1000', 'C1', None, 25, 376.0, None, 23100.0, None, None, 'Lower Marker'), ('2020-02-11 - 10.01.14.HSD1000', 'C1', None, 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker')  ... displaying 10 of 196 total bound parameter sets ...  ('2020-02-11 - 10.01.14.HSD1000', 'F12', None, 25, 444.0, None, 27300.0, None, None, 'Lower Marker'), ('2020-02-11 - 10.01.14.HSD1000', 'F12', None, 1500, 250.0, 250.0, 256.0, None, None, 'Upper Marker'))
# 2020-03-20 22:31:42,315 INFO sqlalchemy.engine.base.Engine COMMIT
# 2020-03-20 22:31:42,320 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("regions")
# 2020-03-20 22:31:42,321 INFO sqlalchemy.engine.base.Engine ()
# 2020-03-20 22:31:42,324 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2020-03-20 22:31:42,327 INFO sqlalchemy.engine.base.Engine INSERT INTO regions (ts_data_id, well_id, samp_desc, from_bp, to_bp, avg_size, concentration, region_mol, pct_total, region_comment) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
# 2020-03-20 22:31:42,328 INFO sqlalchemy.engine.base.Engine (('2020-02-11 - 10.01.14.HSD1000', 'A1', '2020_02_08_Rio_P11_A1', 100, 1000, 235, 335, 2560, 83.3, None), ('2020-02-11 - 10.01.14.HSD1000', 'B1', None, 100, 1000, 371, 358, 1740, 82.17, None), ('2020-02-11 - 10.01.14.HSD1000', 'C1', None, 100, 1000, 336, 282, 1540, 80.63, None), ('2020-02-11 - 10.01.14.HSD1000', 'D1', None, 100, 1000, 350, 857, 4390, 89.41, None), ('2020-02-11 - 10.01.14.HSD1000', 'E1', None, 100, 1000, 339, 353, 1880, 81.95, None), ('2020-02-11 - 10.01.14.HSD1000', 'A2', None, 100, 1000, 298, 386, 2420, 87.8, None), ('2020-02-11 - 10.01.14.HSD1000', 'B2', None, 100, 1000, 287, 490, 3210, 89.45, None), ('2020-02-11 - 10.01.14.HSD1000', 'C2', None, 100, 1000, 367, 497, 2390, 85.74, None)  ... displaying 10 of 91 total bound parameter sets ...  ('2020-02-11 - 10.01.14.HSD1000', 'E12', None, 100, 1000, 357, 938, 4780, 94.2, None), ('2020-02-11 - 10.01.14.HSD1000', 'F12', None, 100, 1000, 314, 725, 4440, 91.19, None))
# 2020-03-20 22:31:42,331 INFO sqlalchemy.engine.base.Engine COMMIT

# %%
session.new
# Out:
# IdentitySet([])

# %%
session.commit()

# %%
for instance in session.query(Peak):
    print(instance.ts_data_id, instance.well_id, instance.peak_id)
# Out:
# 2020-03-19 02:56:53,008 INFO sqlalchemy.engine.base.Engine SELECT peaks.ts_data_id AS peaks_ts_data_id, peaks.well_id AS peaks_well_id, peaks.size AS peaks_size, peaks.cal_conc AS peaks_cal_conc, peaks.peak_mol AS peaks_peak_mol, peaks.int_area AS peaks_int_area, peaks.peak_id AS peaks_peak_id
# FROM peaks
# 2020-03-19 02:56:53,009 INFO sqlalchemy.engine.base.Engine ()
# (u'2019-12-18 - 11.45.28.HSD1000', u'A1', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G7', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A9', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G8', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F8', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E8', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D8', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C8', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B8', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A8', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B1', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B6', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D7', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C7', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B7', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A7', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H6', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G6', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F6', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D6', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B9', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C9', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D9', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E9', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G12', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F12', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E12', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D12', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C12', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B12', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G11', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D11', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C11', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B11', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A11', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G10', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D10', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C10', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B10', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A10', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F9', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C6', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F7', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A6', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H3', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F3', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E3', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D3', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C3', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H5', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B3', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A3', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H2', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G2', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F2', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E2', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D2', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C2', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B2', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A2', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H1', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G1', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F1', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E1', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D1', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C1', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G3', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H12', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G5', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E4', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B5', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A5', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D5', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E5', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F5', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G4', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F4', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C5', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'C4', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'B4', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'D4', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A4', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H7', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H11', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E10', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F10', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A12', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E6', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H10', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E11', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H8', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G9', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H4', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F11', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H9', 1)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H9', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F11', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H4', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'G9', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H8', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E11', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H10', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E6', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'A12', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'F10', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'E10', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H11', 2)
# (u'2019-12-18 - 11.45.28.HSD1000', u'H7', 2)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A1', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C8', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F9', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E9', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B9', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A9', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H8', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G8', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F8', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E8', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D8', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B8', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H9', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A8', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H7', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G7', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F7', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E7', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D7', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B7', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B1', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H6', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G9', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A10', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F6', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F11', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G12', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F12', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E12', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D12', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C12', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B12', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A12', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H11', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G11', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E11', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B10', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D11', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B11', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A11', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H10', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G10', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F10', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E10', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D10', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C10', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G6', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A7', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E6', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B4', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D6', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G3', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F3', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E3', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D3', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B3', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A3', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H2', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G2', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F2', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E2', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D2', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C2', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B2', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A2', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H1', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G1', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F1', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E1', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D1', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C1', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A4', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H3', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C4', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B5', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C6', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'B6', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A6', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H5', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G5', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F5', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E5', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D5', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H12', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'A5', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'H4', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'G4', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'F4', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'E4', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'D4', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C11', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C3', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C9', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C7', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C5', 1)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C5', 2)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C7', 2)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C9', 2)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C3', 2)
# (u'2020-02-27 - 12.12.58.HSD1000', u'C11', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'E11', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'F11', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'B11', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A11', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'C10', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'E10', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'F10', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'D10', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'G11', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'G10', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'H10', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'H11', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'C11', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'B10', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'C11', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A10', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'D11', 1)
# (u'2020-02-26 - 13.53.51.HSD1000', u'D11', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'D11', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'H11', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'B10', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'B10', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A10', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'B10', 4)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A10', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A10', 4)
# (u'2020-02-26 - 13.53.51.HSD1000', u'G11', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A10', 5)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A10', 6)
# (u'2020-02-26 - 13.53.51.HSD1000', u'G10', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'H10', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'E10', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'F10', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'D10', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'C10', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'H10', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'G10', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'D10', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'B10', 5)
# (u'2020-02-26 - 13.53.51.HSD1000', u'F10', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A11', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'B11', 2)
# (u'2020-02-26 - 13.53.51.HSD1000', u'E10', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'C10', 3)
# (u'2020-02-26 - 13.53.51.HSD1000', u'B10', 6)
# (u'2020-02-26 - 13.53.51.HSD1000', u'A10', 7)
# (u'2020-02-26 - 13.53.51.HSD1000', u'H10', 4)
# (u'2020-02-03 - 11.25.42.HSD1000', u'A1', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'D6', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'C4', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'A5', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'C5', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'D5', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'E5', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'F5', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'G5', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'H5', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B6', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'C6', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'E6', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'A4', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'F6', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'G6', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'H6', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'A7', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B7', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'C7', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'D7', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'E7', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'F7', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'G7', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B4', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'D4', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'H3', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'G3', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'C1', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'D1', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'F1', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'G1', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'H1', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'A2', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'C2', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'E2', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'G2', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'H2', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'A3', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'H7', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'D3', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'E3', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'C3', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'E1', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'A6', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B3', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B5', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'F3', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B1', 1)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B1', 2)
# (u'2020-02-03 - 11.25.42.HSD1000', u'F3', 2)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B3', 2)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B5', 2)
# (u'2020-02-03 - 11.25.42.HSD1000', u'B5', 3)
# (u'2020-02-03 - 11.25.42.HSD1000', u'A6', 2)
# (u'2020-02-03 - 11.25.42.HSD1000', u'E1', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A1', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C6', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D9', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B9', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A9', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H8', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G8', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F8', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D8', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C8', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B8', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A8', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H7', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G7', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F7', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E7', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D7', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B7', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A7', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B1', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G6', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F6', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E6', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E9', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F9', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G9', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E11', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F12', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E12', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D12', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C12', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B12', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A12', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H11', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G11', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F11', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D11', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H9', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B11', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A11', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H10', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G10', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E10', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D10', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C10', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B10', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A10', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D6', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H6', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B6', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C4', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A4', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H3', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G3', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F3', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A6', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D3', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B3', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A3', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H2', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G2', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F2', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E2', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C2', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B2', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A2', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H1', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F1', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E1', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D1', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B4', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E3', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D4', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'A5', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H5', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F5', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E5', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D5', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'B5', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H12', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G4', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F4', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E4', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E8', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H4', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G1', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D2', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G12', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C1', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C9', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C11', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C7', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G5', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C5', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F10', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C3', 1)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C3', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'F10', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C5', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G5', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C7', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C11', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C9', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'C1', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G12', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'D2', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'G1', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'H4', 2)
# (u'2020-03-03 - 16.22.56.HSD1000', u'E8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H7', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F4', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G9', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C7', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D6', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E7', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G3', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H9', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B4', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B3', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B6', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H2', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E2', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H11', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F5', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D11', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F10', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G10', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F3', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B11', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B7', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G4', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A4', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D4', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A6', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C9', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C11', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D9', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C12', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E10', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A8', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C4', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G11', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D3', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G8', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C5', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E11', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A10', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F2', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G6', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A2', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A5', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E12', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G7', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F11', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C8', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C1', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E6', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A3', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F6', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H10', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G2', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C6', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D8', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B8', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G5', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D12', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B10', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C10', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F8', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D10', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F7', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F9', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E4', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E5', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E3', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D5', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C3', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E9', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H3', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H5', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F12', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C2', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H8', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E1', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D1', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H4', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B1', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B5', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B12', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A7', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A9', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D7', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B9', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E8', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D2', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H6', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A11', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A11', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H6', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D2', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B9', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A1', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A12', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A12', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B2', 1)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D7', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A9', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A7', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B2', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B5', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B1', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H4', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E1', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C2', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F12', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H5', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E9', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A1', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C3', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D5', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E3', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E5', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E4', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F9', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H3', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F7', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D10', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B10', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D12', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G5', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H10', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F6', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A3', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C6', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G2', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C1', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B12', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F11', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E6', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G7', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E12', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A2', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F2', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C10', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A10', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E11', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D3', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G11', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D1', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C4', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C5', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E10', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D9', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C11', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C12', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B12', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C9', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D8', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G6', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A6', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A4', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A5', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G4', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D4', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D1', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G10', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B11', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D8', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F10', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F3', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D11', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F5', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A1', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H11', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E2', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B6', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B7', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B4', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H9', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H8', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C10', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G3', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A5', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H2', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E7', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D6', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C7', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G6', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B7', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D1', 4)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G9', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B3', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B2', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F4', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B3', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H2', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A8', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H3', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'E6', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H7', 2)
# (u'2020-02-11 - 10.01.14.HSD1000', u'G2', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C6', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H3', 4)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C5', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'F3', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B11', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A12', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'D4', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B8', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A12', 4)
# (u'2020-02-11 - 10.01.14.HSD1000', u'B3', 4)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H7', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'C12', 3)
# (u'2020-02-11 - 10.01.14.HSD1000', u'A1', 4)
# (u'2020-02-11 - 10.01.14.HSD1000', u'H7', 4)
